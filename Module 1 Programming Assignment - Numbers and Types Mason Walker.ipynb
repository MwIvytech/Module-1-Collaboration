# %%
# 3.1 secs per min * min per hour answer is 3600
60 * 60
# Out:
# 3600

# %%
# 3.2 assign variable
seconds_per_hour = 60 * 60
seconds_per_hour
# Out:
# 3600

# %%
# 3.3 use of variable secs per day is 86400
seconds_per_hour = 60*60
seconds_per_hour * 24
# Out:
# 86400

# %%
# 3.4 storing secs per day in a variable
seconds_per_hour = 60*60
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %%
#3.5 secs per day / secs per hour
seconds_per_hour = 60*60
seconds_per_day = seconds_per_hour * 24
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
# 3.6 secs per
